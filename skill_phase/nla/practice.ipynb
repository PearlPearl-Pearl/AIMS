# %% [markdown]
# Least Squares Problem

# %%
A = [1 1; 1 1.5; 1 2.0; 1 2.5; 1 3.0]
# Out:
# 5×2 Matrix{Float64}:
#  1.0  1.0
#  1.0  1.5
#  1.0  2.0
#  1.0  2.5
#  1.0  3.0

# %%
b = [1.1; 1.2; 1.3; 1.3; 1.4]
# Out:
# 5-element Vector{Float64}:
#  1.1
#  1.2
#  1.3
#  1.3
#  1.4

# %%
x = A\b
# Out:
# 2-element Vector{Float64}:
#  0.9799999999999994
#  0.14000000000000004

# %%
using Plots

# %%
?plot
# Out:
# search: plot plot! pyplot plotly plot3d float split splat Plots plot3d! boxplot
#   The main plot command. Use plot to create a new plot object, and plot! to
#   add to an existing one:
#
#       plot(args...; kw...)                  # creates a new plot window, and sets it to be the current
#       plot!(args...; kw...)                 # adds to the `current`
#       plot!(plotobj, args...; kw...)        # adds to the plot `plotobj`
#
#   There are lots of ways to pass in data, and lots of keyword arguments...
#   just try it and it will likely work as expected. When you pass in matrices,
#   it splits by columns. To see the list of available attributes, use the
#   plotattr(attr) function, where attr is the symbol :Series, :Subplot, :Plot,
#   or :Axis. Pass any attribute to plotattr as a String to look up its
#   docstring, e.g., plotattr("seriestype").
#
#   ────────────────────────────────────────────────────────────────────────────
#
# ...

# %%
s=A[:,2]
# Out:
# 5-element Vector{Float64}:
#  1.0
#  1.5
#  2.0
#  2.5
#  3.0

# %%
scatter(s,b)
plot!(A*x)

# %%
r=b-(A*x)
# Out:
# 5-element Vector{Float64}:
#  -0.01999999999999935
#   0.010000000000000453
#   0.04000000000000048
#  -0.029999999999999583
#   4.440892098500626e-16

# %%
using LinearAlgebra

# %%
norm(r)
# Out:
# 0.05477225575051658
